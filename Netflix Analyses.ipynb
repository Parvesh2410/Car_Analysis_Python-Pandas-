# %%
import pandas as pd

# %%
net = pd.read_csv(r"C:\Users\kparv\OneDrive\Documents\8. Netflix Dataset.csv")

# %%
net
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
net.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
net.shape
# Out:
# (7789, 11)

# %%
net.index
# Out:
# RangeIndex(start=0, stop=7789, step=1)

# %%
net.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
net.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
net['Type'].unique()
# Out:
# array(['International TV Shows, TV Dramas, TV Sci-Fi & Fantasy',
#        'Dramas, International Movies',
#        'Horror Movies, International Movies',
#        'Action & Adventure, Independent Movies, Sci-Fi & Fantasy',
#        'Dramas', 'International TV Shows, TV Dramas, TV Mysteries',
#        'Horror Movies, International Movies, Thrillers',
#        'Dramas, Thrillers',
#        'Crime TV Shows, International TV Shows, TV Dramas',
#        'Crime TV Shows, Docuseries, International TV Shows',
#        'Documentaries, International Movies, Sports Movies',
#        'Independent Movies, Sci-Fi & Fantasy, Thrillers',
#        'Dramas, International Movies, Thrillers',
#        'International TV Shows, TV Dramas',
#        'Comedies, Dramas, Independent Movies', 'Sports Movies',
#        'Dramas, Independent Movies, International Movies',
#        'Action & Adventure, Dramas, International Movies',
#        'Anime Series, International TV Shows', 'Documentaries',
# ...

# %%
net["Rating"].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# ## Task. 1) Is there any Duplicate Record in this dataset ? If yes, then remove the duplicate records.

# %%
net.shape
# Out:
# (7789, 11)

# %%
net.duplicated() # In the form of boolean
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7784    False
# 7785    False
# 7786    False
# 7787    False
# 7788    False
# Length: 7789, dtype: bool

# %%
net[net.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
net.drop_duplicates(inplace = True)  # - To delete duplicate value permanently.

# %%
net[net.duplicated()] # - To verify that duplicates removed or not.
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %%
net.shape # - previously it was 7789 now it is 7787.
# Out:
# (7787, 11)

# %% [markdown]
#  ## Task. 2) Is there any Null Value present in any column ? Show with Heat-map.

# %%
net.isnull() # In the boolean form
# Out:
#       Show_Id  Category  Title  Director   Cast  Country  Release_Date  \
# 0       False     False  False      True  False    False         False
# 1       False     False  False     False  False    False         False
# 2       False     False  False     False  False    False         False
# 3       False     False  False     False  False    False         False
# 4       False     False  False     False  False    False         False
# ...       ...       ...    ...       ...    ...      ...           ...
# 7784    False     False  False     False  False    False         False
# 7785    False     False  False     False  False    False         False
# 7786    False     False  False      True  False     True         False
# 7787    False     False  False      True  False    False         False
# 7788    False     False  False     False   True    False         False
#
#       Rating  Duration   Type  Description
# 0      False     False  False        False
# ...

# %%
net[net.isnull()] # to show as data frame
# Out:
#      Show_Id Category Title Director Cast Country Release_Date Rating  \
# 0        NaN      NaN   NaN      NaN  NaN     NaN          NaN    NaN
# 1        NaN      NaN   NaN      NaN  NaN     NaN          NaN    NaN
# 2        NaN      NaN   NaN      NaN  NaN     NaN          NaN    NaN
# 3        NaN      NaN   NaN      NaN  NaN     NaN          NaN    NaN
# 4        NaN      NaN   NaN      NaN  NaN     NaN          NaN    NaN
# ...      ...      ...   ...      ...  ...     ...          ...    ...
# 7784     NaN      NaN   NaN      NaN  NaN     NaN          NaN    NaN
# 7785     NaN      NaN   NaN      NaN  NaN     NaN          NaN    NaN
# 7786     NaN      NaN   NaN      NaN  NaN     NaN          NaN    NaN
# 7787     NaN      NaN   NaN      NaN  NaN     NaN          NaN    NaN
# 7788     NaN      NaN   NaN      NaN  NaN     NaN          NaN    NaN
#
#      Duration Type Description
# 0         NaN  NaN         NaN
# 1         NaN  NaN         NaN
# ...

# %%
net.isnull().sum() # To know the count of null values in each column
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
# Out:
# Show_Id  Category  Title  Director  Cast   Country  Release_Date  Rating  Duration  Type   Description
# False    False     False  False     False  False    False         False   False     False  False          4809
#                           True      False  False    False         False   False     False  False          1834
#                           False     True   False    False         False   False     False  False           381
#                           True      False  True     False         False   False     False  False           242
#                                     True   False    False         False   False     False  False           241
#                           False     False  True     False         False   False     False  False           167
#                           True      True   True     False         False   False     False  False            58
# ...

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
sns.heatmap(net.isnull())
plt.show()

# %% [markdown]
# ## Question 1 - Q. 1) For 'Breaking Bad', what is the Show Id and Who is the Director of this show ?

# %%
net.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
net["Title"] #- Syntax to slecet any column in a data set.
# Out:
# 0                                            3%
# 1                                         07:19
# 2                                         23:59
# 3                                             9
# 4                                            21
#                          ...
# 7784                                       Zozo
# 7785                                     Zubaan
# 7786                          Zulu Man in Japan
# 7787                      Zumbo's Just Desserts
# 7788    ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
# Name: Title, Length: 7789, dtype: object

# %%
net["Title"].isin(['Breaking Bad'])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7784    False
# 7785    False
# 7786    False
# 7787    False
# 7788    False
# Name: Title, Length: 7789, dtype: bool

# %%
# isin ()  - To show all records including particular elements.

# %%
net[net["Title"].isin(['Breaking Bad'])]
# Out:
#      Show_Id Category         Title Director  \
# 1089   s1090  TV Show  Breaking Bad      NaN
#
#                                                    Cast        Country  \
# 1089  Bryan Cranston, Aaron Paul, Anna Gunn, Dean No...  United States
#
#         Release_Date Rating   Duration  \
# 1089  August 2, 2013  TV-MA  5 Seasons
#
#                                          Type  \
# 1089  Crime TV Shows, TV Dramas, TV Thrillers
#
#                                             Description
# 1089  A high school chemistry teacher dying of cance...

# %%
# str.contains() -  To get all records that contains a given string.

# %%
net['Title'].str.contains('Friends')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7784    False
# 7785    False
# 7786    False
# 7787    False
# 7788    False
# Name: Title, Length: 7789, dtype: bool

# %%
net[net['Title'].str.contains('Breaking Bad')]
# Out:
#      Show_Id Category                                              Title  \
# 1089   s1090  TV Show                                       Breaking Bad
# 1945   s1946    Movie                    El Camino: A Breaking Bad Movie
# 6832   s6831    Movie  The Road to El Camino: Behind the Scenes of El...
#
#             Director                                               Cast  \
# 1089             NaN  Bryan Cranston, Aaron Paul, Anna Gunn, Dean No...
# 1945  Vince Gilligan                                         Aaron Paul
# 6832             NaN                                                NaN
#
#             Country      Release_Date Rating   Duration  \
# 1089  United States    August 2, 2013  TV-MA  5 Seasons
# 1945  United States  October 11, 2019  TV-MA    123 min
# 6832  United States  October 29, 2019  TV-14     14 min
#
#                                          Type  \
# 1089  Crime TV Shows, TV Dramas, TV Thrillers
# 1945                        Dramas, Thrillers
# ...

# %% [markdown]
# ## Question 2 - In which year the highest number of the TV Shows & Movies were released ? Show with Bar Graph.

# %%
net.dtypes # we checked data types as we need release date, which suppose to be in date time format, but here it is different forbmat.
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
net["Release_Date"].value_counts()
# Out:
# January 1, 2020      118
# November 1, 2019      94
# December 31, 2019     76
# March 1, 2018         76
# October 1, 2018       72
#                     ...
# October 12, 2014       1
# March 22, 2020         1
# March 31, 2013         1
# December 12, 2019      1
# January 11, 2020       1
# Name: Release_Date, Length: 1565, dtype: int64

# %%
net['R_Date'] = pd.to_datetime(net['Release_Date']) # Added a new column "R_date" in date time format.

# %%
net.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
net["R_Date"].dt.year.value_counts() # It counts shows and movie release in each year in R_date column
# Out:
# 2019.0    2154
# 2020.0    2010
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: R_Date, dtype: int64

# %%
net["R_Date"].dt.month.value_counts()
# Out:
# 12.0    833
# 10.0    785
# 1.0     757
# 11.0    738
# 3.0     669
# 9.0     620
# 8.0     618
# 4.0     602
# 7.0     600
# 5.0     543
# 6.0     542
# 2.0     472
# Name: R_Date, dtype: int64

# %%
net["R_Date"].dt.week.value_counts()
# Out:
# C:\Users\kparv\AppData\Local\Temp\ipykernel_10032\2762837146.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   net["R_Date"].dt.week.value_counts()
# 1.0     398
# 44.0    330
# 40.0    297
# 31.0    256
# 9.0     235
# 18.0    220
# 48.0    209
# 13.0    199
# 35.0    197
# 50.0    192
# 26.0    189
# 5.0     184
# 27.0    179
# 39.0    174
# 14.0    165
# 22.0    147
# 42.0    142
# 49.0    141
# 37.0    140
# 11.0    140
# 46.0    139
# 51.0    139
# 33.0    138
# 52.0    138
# 10.0    133
# 23.0    129
# 47.0    128
# 16.0    126
# 20.0    123
# 7.0     123
# 25.0    121
# 36.0    119
# 41.0    119
# 43.0    118
# 38.0    117
# 2.0     113
# 53.0    110
# 17.0    108
# 3.0     107
# 45.0    102
# 21.0    100
# 28.0    100
# 32.0     99
# 24.0     99
# 29.0     99
# 30.0     94
# 19.0     94
# 34.0     93
# 12.0     90
# 15.0     89
# 8.0      86
# 6.0      77
# 4.0      75
# ...

# %%
net["R_Date"].dt.day.value_counts()
# Out:
# 1.0     2069
# 15.0     644
# 31.0     274
# 2.0      247
# 16.0     240
# 20.0     219
# 10.0     213
# 5.0      208
# 19.0     203
# 8.0      190
# 22.0     185
# 30.0     182
# 25.0     180
# 18.0     178
# 26.0     174
# 28.0     172
# 21.0     172
# 6.0      165
# 7.0      162
# 14.0     161
# 12.0     156
# 27.0     153
# 13.0     153
# 17.0     153
# 4.0      152
# 23.0     138
# 24.0     136
# 29.0     130
# 3.0      127
# 11.0     123
# 9.0      120
# Name: R_Date, dtype: int64

# %%
net['R_Date'].dt.year.value_counts().plot(kind= 'bar')
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Question 3 - How many Movies & TV Shows are in the dataset ? Show with Bar Graph.

# %%
net.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
net.groupby('Category')

# %%
net.groupby('Category').Category.count()
# Out:
# Category
# Movie      5379
# TV Show    2410
# Name: Category, dtype: int64

# %%
net.groupby('Category').Category.count().plot (kind= 'bar')
# Out:
# <AxesSubplot: xlabel='Category'>

# %% [markdown]
# ## Question 4 - Show all the Movies that were released in year 2019.

# %%
net.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     R_Date
# 0  In a future where the elite inhabit an island ... 2020-08-14
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23

# %%
net['Year'] = net['R_Date'].dt.year #new column created as I wanted a specific year.

# %%
net.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     R_Date    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
net[(net['Category'] == 'Movie') & (net['Year'] == 2019)]  #filtered movie from category column and 2019 from year column
# Out:
#      Show_Id Category                     Title  \
# 7         s8    Movie                       187
# 8         s9    Movie                       706
# 13       s14    Movie                     2,215
# 15       s16    Movie                    Oct-01
# 18       s19    Movie                    15-Aug
# ...      ...      ...                       ...
# 7771   s7770    Movie  Zindagi Na Milegi Dobara
# 7775   s7774    Movie            Zoé: Panoramas
# 7776   s7775    Movie                    Zodiac
# 7780   s7779    Movie                Zombieland
# 7785   s7784    Movie                    Zubaan
#
#                                    Director  \
# 7                            Kevin Reynolds
# 8                             Shravan Kumar
# 13                      Nottapon Boonprakob
# 15                           Kunle Afolayan
# 18                       Swapnaneel Jayakar
# ...                                     ...
# 7771                            Zoya Akhtar
# ...

# %% [markdown]
# ## Question 5 -  Show only the Titles of all TV Shows that were released in Brazil only.

# %%
net.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     R_Date    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
net[(net['Category'] == 'TV Show') & (net['Country'] == 'Brazil')] ['Title'].count()
# Out:
# 26

# %%
net[ (net['Category']=='Movie') & (net['Country']=='Germany') ] ['Title'].count()
# Out:
# 42

# %%
net[ (net['Category']=='Movie') & (net['Country']=='Germany') ] ['Title'].value_counts()
# Out:
# 3 Türken & ein Baby                           1
# Pettersson and Findus 2                       1
# Kidnapping Stella                             1
# Latte and the Magic Waterstone                1
# Lommbock                                      1
# Look Who's Back                               1
# Making Unorthodox                             1
# My Fuhrer                                     1
# Offline - Das leben ist kein bonuslevel       1
# Pedal the World                               1
# Right Here Right Now                          1
# A Heavy Heart                                 1
# Rising High                                   1
# Rock My Heart                                 1
# Schubert In Love                              1
# Stereo                                        1
# System Crasher                                1
# The Lives of Others                           1
# The NSU-Complex                               1
# The Physician                                 1
# ...

# %%
net[ (net['Category']=='Movie') & (net['Country']=='Germany') ] ['Cast'].count()
# Out:
# 37

# %% [markdown]
# ## Question 6 - Show Top 10 Directors, who gave the highest number of TV Shows & Movies to Netflix ?

# %%
net.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
net['Director'].value_counts().head(10)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Robert Rodriguez           8
# Name: Director, dtype: int64

# %% [markdown]
# ## Question 7- Show all the Records, where "Category is Movie and Type is Comedies" or "Country is India".

# %%
  net[(net['Category']=='Movie') & (net['Type']== 'Comedies')]
# Out:
#      Show_Id Category                        Title                Director  \
# 33       s34    Movie                 #realityhigh        Fernando Lebrija
# 72       s73    Movie                     17 Again             Burr Steers
# 84       s85    Movie                    21 & Over  Jon Lucas, Scott Moore
# 148     s149    Movie         A Bad Moms Christmas  Jon Lucas, Scott Moore
# 174     s175    Movie  A Futile and Stupid Gesture              David Wain
# ...      ...      ...                          ...                     ...
# 7341   s7340    Movie         Undercover Brother 2            Leslie Small
# 7590   s7589    Movie            Where's the Money         Scott Zabielski
# 7623   s7622    Movie                    Wild Oats            Andy Tennant
# 7634   s7633    Movie                 Wine Country             Amy Poehler
# 7664   s7663    Movie                      Work It           Laura Terruso
#
#                                                    Cast  \
# ...

# %%
net[(net['Category']=='Movie') & (net['Type']== 'Comedies') | (net['Country']=='India')]
# Out:
#      Show_Id Category                     Title            Director  \
# 8         s9    Movie                       706       Shravan Kumar
# 9        s10    Movie                      1920        Vikram Bhatt
# 18       s19    Movie                    15-Aug  Swapnaneel Jayakar
# 20       s21    Movie      ​​Kuch Bheege Alfaaz                Onir
# 21       s22    Movie              ​Goli Soda 2        Vijay Milton
# ...      ...      ...                       ...                 ...
# 7766   s7765    Movie                      Zero          Aanand Rai
# 7771   s7770    Movie  Zindagi Na Milegi Dobara         Zoya Akhtar
# 7778   s7777    Movie                  Zokkomon    Satyajit Bhatkal
# 7782   s7781    Movie                       Zoo        Shlok Sharma
# 7785   s7784    Movie                    Zubaan         Mozez Singh
#
#                                                    Cast Country  \
# 8     Divya Dutta, Atul Kulkarni, Mohan Agashe, Anup...   India
# ...

# %% [markdown]
# ## Question 8 - In how many movies/shows, Tom Cruise was cast ?

# %%
net[net['Cast']=='Tom Cruise'] #No result because there is no column in cast which only contains Tom Cruise as a cast.
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, R_Date, Year]
# Index: []

# %%
net[net['Cast'].str.contains('Tom cruise')] #some columns contains null values and we have to delete it.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 net[net['Cast'].str.contains('Tom cruise')]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:3795, in DataFrame.__getitem__(self, key)
#    3792     return self.where(key)
#    3794 # Do we have a (boolean) 1d indexer?
# -> 3795 if com.is_bool_indexer(key):
#    3796     return self._getitem_bool_array(key)
#    3798 # We are left with two options: a single key, and a collection of keys,
#    3799 # We interpret tuples as collections only for non-MultiIndex
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\common.py:135, in is_bool_indexer(key)
#     131     na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     132     if lib.infer_dtype(key_array) == "boolean" and isna(key_array).any():
# ...

# %%
net_new = net.dropna() # I created a new data frame which contains non null values.

# %%
net_new
# Out:
#      Show_Id Category       Title           Director  \
# 1         s2    Movie       07:19  Jorge Michel Grau
# 2         s3    Movie       23:59       Gilbert Chan
# 3         s4    Movie           9        Shane Acker
# 4         s5    Movie          21     Robert Luketic
# 5         s6  TV Show          46        Serdar Akar
# ...      ...      ...         ...                ...
# 7780   s7779    Movie  Zombieland    Ruben Fleischer
# 7782   s7781    Movie         Zoo       Shlok Sharma
# 7783   s7782    Movie        Zoom       Peter Hewitt
# 7784   s7783    Movie        Zozo        Josef Fares
# 7785   s7784    Movie      Zubaan        Mozez Singh
#
#                                                    Cast  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
net_new.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date Rating Duration                                 Type  \
# 1  December 23, 2016  TV-MA   93 min         Dramas, International Movies
# 2  December 20, 2018      R   78 min  Horror Movies, International Movies
#
#                                          Description     R_Date    Year
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0
# 2  When an army recruit is found dead, his fellow... 2018-12-20  2018.0

# %%
net_new[net_new['Cast'].str.contains('Tom Cruise')] # df.str.contains show all the results which conatins mentioned string in this the string was Tom cruise
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description     R_Date    Year
# 3860  Through chance, human action, past history and... 2020-01-01  2020.0
# 5071  A fast-talking yuppie is forced to slow down w... 2019-07-01  2019.0

# %% [markdown]
# # Question 9 - What are the different Ratings defined by Netflix ?

# %%
net['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
net['Rating'].nunique()
# Out:
# 14

# %% [markdown]
# # Question 10 -  How many Movies got the 'TV-14' rating, in Spain ?

# %%
net.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     R_Date    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
net[(net['Category']=='Movie') & (net['Rating']=='TV-14') & (net['Country']=='Spain')]
# Out:
#      Show_Id Category                     Title                  Director  \
# 1054   s1055    Movie              Born in Gaza                Hernán Zin
# 1185   s1186    Movie         Camarón: The Film            Alexis Morante
# 1957   s1958    Movie             El fin de ETA            Justin Webster
# 4772   s4773    Movie  Parchís: the Documentary            Daniel Arasanz
# 5334   s5334    Movie        Sad Hill Unearthed     Guillermo de Oliveira
# 5678   s5678    Movie           Smoke & Mirrors         Alberto Rodríguez
# 6394   s6393    Movie                 The Giant  Aitor Arregi, Jon Garaño
# 6506   s6505    Movie       The Invisible Guest               Paulo Oriol
#
#                                                    Cast Country  \
# 1054                                                NaN   Spain
# 1185                                         Juan Diego   Spain
# 1957                                                NaN   Spain
# ...

# %%
net[(net['Category']=='Movie') & (net['Rating']=='TV-14') & (net['Country']=='Spain')].count()
# Out:
# Show_Id         8
# Category        8
# Title           8
# Director        8
# Cast            4
# Country         8
# Release_Date    8
# Rating          8
# Duration        8
# Type            8
# Description     8
# R_Date          8
# Year            8
# dtype: int64

# %%
net[(net['Category']=='Movie') & (net['Rating']=='TV-14') & (net['Country']=='Spain')].shape
# Out:
# (8, 13)

# %% [markdown]
# # Question 11 -  How many TV Shows got the 'R' rating, after year 2017 ?

# %%
net.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     R_Date    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
net[(net['Category']=='TV Show') & (net['Rating']=='TV-MA') & (net['Year'] > 2017)]
# Out:
#      Show_Id Category            Title              Director  \
# 0         s1  TV Show               3%                   NaN
# 11       s12  TV Show             1983                   NaN
# 12       s13  TV Show             1994  Diego Enrique Osorno
# 26       s27  TV Show         (Un)Well                   NaN
# 29       s30  TV Show         #blackAF                   NaN
# ...      ...      ...              ...                   ...
# 7727   s7726  TV Show  You Cannot Hide                   NaN
# 7740   s7739  TV Show  Young Wallander                   NaN
# 7754   s7753  TV Show    Yummy Mummies                   NaN
# 7757   s7756  TV Show         Z Nation                   NaN
# 7781   s7780  TV Show        Zona Rosa                   NaN
#
#                                                    Cast  \
# 0     João Miguel, Bianca Comparato, Michel Gomes, R...
# 11    Robert Więckiewicz, Maciej Musiał, Michalina O...
# 12                                                  NaN
# ...

# %%
net[(net['Category']=='TV Show') & (net['Rating']=='TV-MA') & (net['Year'] > 2017)].count()
# Out:
# Show_Id         859
# Category        859
# Title           859
# Director         79
# Cast            741
# Country         788
# Release_Date    859
# Rating          859
# Duration        859
# Type            859
# Description     859
# R_Date          859
# Year            859
# dtype: int64

# %%
net[(net['Category']=='TV Show') & (net['Rating']=='TV-MA') & (net['Year'] > 2017)].shape
# Out:
# (859, 13)

# %% [markdown]
# # Questions 12 - What is the maximum duration of a Movie/Show on Netflix ?

# %%
net.head(2
    )
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     R_Date    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
net.Duration.unique()
# Out:
# array(['4 Seasons', '93 min', '78 min', '80 min', '123 min', '1 Season',
#        '95 min', '119 min', '118 min', '143 min', '103 min', '89 min',
#        '91 min', '149 min', '144 min', '124 min', '87 min', '110 min',
#        '128 min', '117 min', '100 min', '2 Seasons', '84 min', '99 min',
#        '90 min', '102 min', '104 min', '105 min', '56 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '109 min', '44 min',
#        '75 min', '101 min', '3 Seasons', '37 min', '113 min', '114 min',
#        '130 min', '94 min', '140 min', '135 min', '82 min', '70 min',
#        '121 min', '92 min', '164 min', '53 min', '83 min', '116 min',
#        '86 min', '120 min', '96 min', '126 min', '129 min', '77 min',
#        '137 min', '148 min', '28 min', '122 min', '176 min', '85 min',
#        '22 min', '68 min', '111 min', '29 min', '142 min', '168 min',
#        '21 min', '59 min', '20 min', '98 min', '108 min', '76 min',
# ...

# %%
net.Duration.Max
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[139], line 1
# ----> 1 net.Duration.Max
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'Max'

# %%
#Getting above because the data tyoe is object not numeric because there are seasons available in Duration. I have to convert the data type in numeric first.

# %% [markdown]
# --To split a cloumn into parts use
# #df.str.split(" Sperator", expand = True)

# %%
net[['Minutes' , 'Unit']] = net['Duration'].str.split(' ', expand = True)

# %%
net.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     R_Date    Year  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0
#
#   Minutes     Unit
# 0       4  Seasons
# 1      93      min

# %%
net['Minutes']
# Out:
# 0         4
# 1        93
# 2        78
# 3        80
# 4       123
#        ...
# 7784     99
# 7785    111
# 7786     44
# 7787      1
# 7788     90
# Name: Minutes, Length: 7789, dtype: object

# %%
net['Minutes'].max()
# Out:
# '99'

# %%
net['Minutes'].min()
# Out:
# '1'

# %%
net['Minutes'].mean()
# Out:
# inf

# %% [markdown]
# # Question 13 - Which individual country has the Highest No. of TV Shows ?

# %%
net.head(2
    )
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     R_Date    Year  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0
#
#   Minutes     Unit
# 0       4  Seasons
# 1      93      min

# %%
net.groupby('Country')

# %%
net.groupby('Country').count()
# Out:
#                                                     Show_Id  Category  Title  \
# Country
# Argentina                                                50        50     50
# Argentina, Brazil, France, Poland, Germany, Den...        1         1      1
# Argentina, Chile                                          1         1      1
# Argentina, Chile, Peru                                    1         1      1
# Argentina, France                                         1         1      1
# ...                                                     ...       ...    ...
# Venezuela                                                 1         1      1
# Venezuela, Colombia                                       1         1      1
# Vietnam                                                   5         5      5
# West Germany                                              1         1      1
# Zimbabwe                                                  1         1      1
#
# ...

# %%
net.groupby('Country').value_counts()
# Out:
# Country    Show_Id  Category  Title                              Director                Cast                                                                                                                                                                                                Release_Date        Rating  Duration  Type                                                   Description                                                                                                                                               R_Date      Year    Minutes  Unit
# ...

# %%
# Out:
# C:\Users\kparv\AppData\Local\Temp\ipykernel_10032\3241800089.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   net.groupby('Country').max()
#                                                    Show_Id Category  \
# Country
# Argentina                                              s93  TV Show
# Argentina, Brazil, France, Poland, Germany, Den...    s231    Movie
# Argentina, Chile                                     s6290    Movie
# Argentina, Chile, Peru                               s3826    Movie
# Argentina, France                                    s3044    Movie
# ...                                                    ...      ...
# Venezuela                                            s1951    Movie
# Venezuela, Colombia                                  s4728    Movie
# ...

# %%
net.groupby('Country') where net['Category']=='TV Show'
# Out:
#   Cell In[156], line 1
#     net.groupby('Country') where net['Category']=='TV Show'
#                            ^
# SyntaxError: invalid syntax

# %%
#creating a new dataframe which contains only TV show as a category.

# %%
net_TV = net[net['Category']=='TV Show']

# %%
net_TV.head(2)
# Out:
#   Show_Id Category Title     Director  \
# 0      s1  TV Show    3%          NaN
# 5      s6  TV Show    46  Serdar Akar
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...  Turkey     July 1, 2017
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 5  TV-MA   1 Season    International TV Shows, TV Dramas, TV Mysteries
#
#                                          Description     R_Date    Year  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 5  A genetics professor experiments with a treatm... 2017-07-01  2017.0
#
#   Minutes     Unit
# 0       4  Seasons
# 5       1   Season

# %%
net_TV.Country.value_counts()
# Out:
# United States                                                705
# United Kingdom                                               204
# Japan                                                        157
# South Korea                                                  147
# India                                                         71
#                                                             ...
# Canada, United States, United Kingdom, France, Luxembourg      1
# United States, Italy                                           1
# Chile, Italy                                                   1
# Canada, United Kingdom                                         1
# United States, France, South Korea, Indonesia                  1
# Name: Country, Length: 183, dtype: int64

# %%
net_TV.Country.value_counts().head(1)
# Out:
# United States    705
# Name: Country, dtype: int64

# %% [markdown]
# # Question 14 - How can we sort the dataset by Year ?

# %%
net.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     R_Date    Year  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0
#
#   Minutes     Unit
# 0       4  Seasons
# 1      93      min

# %%
#to sort the dataset by anything - df.sort_values(by="Coumn name")

# %%
net.sort_values(by= 'Year')
# Out:
#      Show_Id Category                         Title              Director  \
# 7115   s7114    Movie          To and From New York  Sorin Dan Mihalcescu
# 1765   s1766  TV Show               Dinner for Five                   NaN
# 5766   s5766    Movie                      Splatter             Joe Dante
# 3248   s3249    Movie       Just Another Love Story          Ole Bornedal
# 3840   s3841    Movie   Mad Ron's Prevues from Hell            Jim Monaco
# ...      ...      ...                           ...                   ...
# 3374   s3375  TV Show                      Kikoriki                   NaN
# 3492   s3493  TV Show           La Familia P. Luche                   NaN
# 3946   s3947  TV Show                         Maron                   NaN
# 5138   s5138  TV Show                  Red vs. Blue                   NaN
# 6066   s6066  TV Show  The Adventures of Figaro Pho                   NaN
#
#                                                    Cast        Country  \
# ...

# %%
net.sort_values(by= 'Year').head(5)
# Out:
#      Show_Id Category                        Title              Director  \
# 7115   s7114    Movie         To and From New York  Sorin Dan Mihalcescu
# 1765   s1766  TV Show              Dinner for Five                   NaN
# 5766   s5766    Movie                     Splatter             Joe Dante
# 3248   s3249    Movie      Just Another Love Story          Ole Bornedal
# 3840   s3841    Movie  Mad Ron's Prevues from Hell            Jim Monaco
#
#                                                    Cast        Country  \
# 7115  Barbara King, Shaana Diya, John Krisiukenas, Y...  United States
# 1765                                                NaN  United States
# 5766  Corey Feldman, Tony Todd, Tara Leigh, Erin Way...  United States
# 3248  Anders W. Berthelsen, Rebecka Hemse, Nikolaj L...        Denmark
# 3840  Nick Pawlow, Jordu Schell, Jay Kushwara, Micha...  United States
#
#            Release_Date Rating  Duration  \
# 7115    January 1, 2008  TV-MA    81 min
# ...

# %% [markdown]
# # Question 15 - Find all the instances where: Category is 'Movie' and Type is 'Dramas' or Category is 'TV Show' & Type is 'Kids' TV'.

# %%
net.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     R_Date    Year  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0
#
#   Minutes     Unit
# 0       4  Seasons
# 1      93      min

# %%
net[(net['Category']=='Movie') & (net['Type']== "Dramas") | (net['Category']=="TV Show") & (net['Type']=="Kids' TV")]
# Out:
#      Show_Id Category                       Title        Director  \
# 4         s5    Movie                          21  Robert Luketic
# 7         s8    Movie                         187  Kevin Reynolds
# 111     s112  TV Show                     44 Cats             NaN
# 170     s171    Movie                A Family Man   Mark Williams
# 232     s233    Movie  A Stoning in Fulham County   Larry Elikann
# ...      ...      ...                         ...             ...
# 7668   s7667  TV Show               World of Winx  Iginio Straffi
# 7717   s7716  TV Show                        Yoko             NaN
# 7719   s7718  TV Show                         YOM             NaN
# 7758   s7757  TV Show                          Z4             NaN
# 7761   s7760  TV Show                   Zak Storm             NaN
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 7     Samuel L. Jackson, John Heard, Kelly Rowan, Cl...
# ...
