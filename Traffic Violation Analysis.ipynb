# %%
import pandas as pd

# %%
tra = pd.read_csv(r"C:\Users\kparv\OneDrive\Documents\3. Police Data.csv")

# %%
tra
# Out:
#        stop_date stop_time  country_name driver_gender  driver_age_raw  \
# 0       1/2/2005      1:55           NaN             M          1985.0
# 1      1/18/2005      8:15           NaN             M          1965.0
# 2      1/23/2005     23:15           NaN             M          1972.0
# 3      2/20/2005     17:15           NaN             M          1986.0
# 4      3/14/2005     10:00           NaN             F          1984.0
# ...          ...       ...           ...           ...             ...
# 65530  12/6/2012     17:54           NaN             F          1987.0
# 65531  12/6/2012     22:22           NaN             M          1954.0
# 65532  12/6/2012     23:20           NaN             M          1985.0
# 65533  12/7/2012      0:23           NaN           NaN             NaN
# 65534  12/7/2012      0:30           NaN             F          1985.0
#
#        driver_age driver_race                   violation_raw  violation  \
# ...

# %%
tra.head()
# Out:
#    stop_date stop_time  country_name driver_gender  driver_age_raw  \
# 0   1/2/2005      1:55           NaN             M          1985.0
# 1  1/18/2005      8:15           NaN             M          1965.0
# 2  1/23/2005     23:15           NaN             M          1972.0
# 3  2/20/2005     17:15           NaN             M          1986.0
# 4  3/14/2005     10:00           NaN             F          1984.0
#
#    driver_age driver_race     violation_raw violation  search_conducted  \
# 0        20.0       White          Speeding  Speeding             False
# 1        40.0       White          Speeding  Speeding             False
# 2        33.0       White          Speeding  Speeding             False
# 3        19.0       White  Call for Service     Other             False
# 4        21.0       White          Speeding  Speeding             False
#
#   search_type   stop_outcome is_arrested stop_duration  drugs_related_stop
# ...

# %%
tra.shape
# Out:
# (65535, 15)

# %% [markdown]
# ## Question 1 - (Cleaning the Data)

# %%
tra.isnull()
# Out:
#        stop_date  stop_time  country_name  driver_gender  driver_age_raw  \
# 0          False      False          True          False           False
# 1          False      False          True          False           False
# 2          False      False          True          False           False
# 3          False      False          True          False           False
# 4          False      False          True          False           False
# ...          ...        ...           ...            ...             ...
# 65530      False      False          True          False           False
# 65531      False      False          True          False           False
# 65532      False      False          True          False           False
# 65533      False      False          True           True            True
# 65534      False      False          True          False           False
#
#        driver_age  driver_race  violation_raw  violation  search_conducted  \
# ...

# %%
tra.isnull().sum()
# Out:
# stop_date                 0
# stop_time                 0
# country_name          65535
# driver_gender          4061
# driver_age_raw         4054
# driver_age             4307
# driver_race            4060
# violation_raw          4060
# violation              4060
# search_conducted          0
# search_type           63056
# stop_outcome           4060
# is_arrested            4060
# stop_duration          4060
# drugs_related_stop        0
# dtype: int64

# %%
tra.drop(columns = 'country_name')
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0       1/2/2005      1:55             M          1985.0        20.0
# 1      1/18/2005      8:15             M          1965.0        40.0
# 2      1/23/2005     23:15             M          1972.0        33.0
# 3      2/20/2005     17:15             M          1986.0        19.0
# 4      3/14/2005     10:00             F          1984.0        21.0
# ...          ...       ...           ...             ...         ...
# 65530  12/6/2012     17:54             F          1987.0        25.0
# 65531  12/6/2012     22:22             M          1954.0        58.0
# 65532  12/6/2012     23:20             M          1985.0        27.0
# 65533  12/7/2012      0:23           NaN             NaN         NaN
# 65534  12/7/2012      0:30             F          1985.0        27.0
#
#       driver_race                   violation_raw  violation  \
# 0           White                        Speeding   Speeding
# ...

# %%
tra
# Out:
#        stop_date stop_time  country_name driver_gender  driver_age_raw  \
# 0       1/2/2005      1:55           NaN             M          1985.0
# 1      1/18/2005      8:15           NaN             M          1965.0
# 2      1/23/2005     23:15           NaN             M          1972.0
# 3      2/20/2005     17:15           NaN             M          1986.0
# 4      3/14/2005     10:00           NaN             F          1984.0
# ...          ...       ...           ...           ...             ...
# 65530  12/6/2012     17:54           NaN             F          1987.0
# 65531  12/6/2012     22:22           NaN             M          1954.0
# 65532  12/6/2012     23:20           NaN             M          1985.0
# 65533  12/7/2012      0:23           NaN           NaN             NaN
# 65534  12/7/2012      0:30           NaN             F          1985.0
#
#        driver_age driver_race                   violation_raw  violation  \
# ...

# %% [markdown]
# - To delete null coulmns permanently

# %%
tra.drop(columns = 'country_name', inplace = True)

# %%
tra
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0       1/2/2005      1:55             M          1985.0        20.0
# 1      1/18/2005      8:15             M          1965.0        40.0
# 2      1/23/2005     23:15             M          1972.0        33.0
# 3      2/20/2005     17:15             M          1986.0        19.0
# 4      3/14/2005     10:00             F          1984.0        21.0
# ...          ...       ...           ...             ...         ...
# 65530  12/6/2012     17:54             F          1987.0        25.0
# 65531  12/6/2012     22:22             M          1954.0        58.0
# 65532  12/6/2012     23:20             M          1985.0        27.0
# 65533  12/7/2012      0:23           NaN             NaN         NaN
# 65534  12/7/2012      0:30             F          1985.0        27.0
#
#       driver_race                   violation_raw  violation  \
# 0           White                        Speeding   Speeding
# ...

# %% [markdown]
# ## Question - 2 (Speeding violation by men and women)
# -Filter data for speeding
#
# -Counts the value of speding violation done by men and women

# %%
tra[tra.violation == 'Speeding']
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0       1/2/2005      1:55             M          1985.0        20.0
# 1      1/18/2005      8:15             M          1965.0        40.0
# 2      1/23/2005     23:15             M          1972.0        33.0
# 4      3/14/2005     10:00             F          1984.0        21.0
# 6       4/1/2005     17:30             M          1969.0        36.0
# ...          ...       ...           ...             ...         ...
# 65527  12/6/2012     15:26             F          1981.0        31.0
# 65529  12/6/2012     16:00             M          1994.0        18.0
# 65530  12/6/2012     17:54             F          1987.0        25.0
# 65531  12/6/2012     22:22             M          1954.0        58.0
# 65534  12/7/2012      0:30             F          1985.0        27.0
#
#       driver_race violation_raw violation  search_conducted search_type  \
# ...

# %%
tra[tra.violation == 'Speeding'].driver_gender
# Out:
# 0        M
# 1        M
# 2        M
# 4        F
# 6        M
#         ..
# 65527    F
# 65529    M
# 65530    F
# 65531    M
# 65534    F
# Name: driver_gender, Length: 37204, dtype: object

# %%
tra[tra.violation == 'Speeding'].driver_gender.value_counts()
# Out:
# M    25517
# F    11686
# Name: driver_gender, dtype: int64

# %% [markdown]
# ## Question - 3 Group By

# %%
tra.groupby("driver_gender")

# %%
tra.groupby("driver_gender").search_conducted.value_counts()
# Out:
# driver_gender  search_conducted
# F              False               15944
#                True                  366
# M              False               43051
#                True                 2113
# Name: search_conducted, dtype: int64

# %%
tra.groupby("driver_gender").search_conducted.sum()
# Out:
# driver_gender
# F     366
# M    2113
# Name: search_conducted, dtype: int64

# %%
tra.search_conducted.value_counts()
# Out:
# False    63056
# True      2479
# Name: search_conducted, dtype: int64

# %% [markdown]
# ## Qusetion - 4 (Mapping & Data-Type Casting)
# - covert stop_duration into int as we can not find mean of a string by mapping - df['cloumn_name'] = df['cloumn_name'].map({old_value : new_value})
# - Taking mean by df['column_name'].mean()

# %%
tra.head()
# Out:
#    stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 0   1/2/2005      1:55             M          1985.0        20.0       White
# 1  1/18/2005      8:15             M          1965.0        40.0       White
# 2  1/23/2005     23:15             M          1972.0        33.0       White
# 3  2/20/2005     17:15             M          1986.0        19.0       White
# 4  3/14/2005     10:00             F          1984.0        21.0       White
#
#       violation_raw violation  search_conducted search_type   stop_outcome  \
# 0          Speeding  Speeding             False         NaN       Citation
# 1          Speeding  Speeding             False         NaN       Citation
# 2          Speeding  Speeding             False         NaN       Citation
# 3  Call for Service     Other             False         NaN  Arrest Driver
# 4          Speeding  Speeding             False         NaN       Citation
#
#   is_arrested stop_duration  drugs_related_stop
# ...

# %% [raw]
# tra

# %%
tra.stop_duration.value_counts()
# Out:
# 0-15 Min     47379
# 16-30 Min    11448
# 30+ Min       2647
# 2                1
# Name: stop_duration, dtype: int64

# %%
tra['stop_duration'] = tra['stop_duration'].map({"0-15 Min" : 7.5, "16-30 Min" : 24, "30+ Min" : 45})

# %%
tra.head(10)
# Out:
#    stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 0   1/2/2005      1:55             M          1985.0        20.0       White
# 1  1/18/2005      8:15             M          1965.0        40.0       White
# 2  1/23/2005     23:15             M          1972.0        33.0       White
# 3  2/20/2005     17:15             M          1986.0        19.0       White
# 4  3/14/2005     10:00             F          1984.0        21.0       White
# 5  3/23/2005      9:45             M          1982.0        23.0       Black
# 6   4/1/2005     17:30             M          1969.0        36.0       White
# 7   6/6/2005     13:20             F          1986.0        19.0       White
# 8  7/13/2005     10:15             M          1970.0        35.0       Black
# 9  7/13/2005     15:45             M          1970.0        35.0       White
#
#                     violation_raw  violation  search_conducted search_type  \
# ...

# %%
tra['stop_duration'].mean()
# Out:
# 12.187420698181345

# %% [markdown]
# ## Question - 5 (GroupBy & Describe)

# %%
tra.head()
# Out:
#    stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 0   1/2/2005      1:55             M          1985.0        20.0       White
# 1  1/18/2005      8:15             M          1965.0        40.0       White
# 2  1/23/2005     23:15             M          1972.0        33.0       White
# 3  2/20/2005     17:15             M          1986.0        19.0       White
# 4  3/14/2005     10:00             F          1984.0        21.0       White
#
#       violation_raw violation  search_conducted search_type   stop_outcome  \
# 0          Speeding  Speeding             False         NaN       Citation
# 1          Speeding  Speeding             False         NaN       Citation
# 2          Speeding  Speeding             False         NaN       Citation
# 3  Call for Service     Other             False         NaN  Arrest Driver
# 4          Speeding  Speeding             False         NaN       Citation
#
#   is_arrested  stop_duration  drugs_related_stop
# ...

# %%
tra.groupby('driver_age')

# %%
tra.groupby('driver_age').violation.value_counts()
# Out:
# driver_age  violation
# 15.0        Moving violation        4
#             Speeding                1
# 16.0        Speeding               18
#             Moving violation        6
#             Registration/plates     5
#                                    ..
# 85.0        Moving violation        1
# 86.0        Speeding                3
#             Moving violation        2
#             Other                   1
# 88.0        Speeding                2
# Name: violation, Length: 333, dtype: int64

# %%
tra.groupby('driver_age').violation.sum()
# Out:
# driver_age
# 15.0    Moving violationSpeedingMoving violationMoving...
# 16.0    SpeedingSpeedingSpeedingSpeedingSpeedingSpeedi...
# 17.0    SpeedingEquipmentEquipmentSpeedingMoving viola...
# 18.0    SpeedingSpeedingEquipmentEquipmentEquipmentSpe...
# 19.0    OtherSpeedingSpeedingSpeedingSpeedingSpeedingS...
#                               ...
# 83.0                             SpeedingMoving violation
# 84.0                             SpeedingSpeedingSpeeding
# 85.0                                     Moving violation
# 86.0    SpeedingSpeedingSpeedingMoving violationOtherM...
# 88.0                                     SpeedingSpeeding
# Name: violation, Length: 73, dtype: object

# %%
tra.groupby('driver_age').violation.describe()
# Out:
#            count unique               top  freq
# driver_age
# 15.0           5      2  Moving violation     4
# 16.0          34      5          Speeding    18
# 17.0         449      5          Speeding   338
# 18.0        1344      5          Speeding   980
# 19.0        2388      5          Speeding  1655
# ...          ...    ...               ...   ...
# 83.0           2      2          Speeding     1
# 84.0           3      1          Speeding     3
# 85.0           1      1  Moving violation     1
# 86.0           6      3          Speeding     3
# 88.0           2      1          Speeding     2
#
# [73 rows x 4 columns]

# %%
tra.groupby('violation')

# %%
tra.groupby('violation').driver_age.value_counts()
# Out:
# violation  driver_age
# Equipment  23.0          385
#            21.0          374
#            22.0          370
#            20.0          348
#            24.0          329
#                         ...
# Speeding   84.0            3
#            86.0            3
#            88.0            2
#            15.0            1
#            83.0            1
# Name: driver_age, Length: 333, dtype: int64

# %%
tra.groupby('violation').driver_age.sum()
# Out:
# violation
# Equipment               206161.0
# Moving violation        436282.0
# Other                   140340.0
# Registration/plates      73151.0
# Seat belt                   91.0
# Speeding               1234707.0
# Name: driver_age, dtype: float64

# %%
tra.groupby('violation').driver_age.describe()
# Out:
#                        count       mean        std   min   25%   50%   75%  \
# violation
# Equipment             6507.0  31.682957  11.380671  16.0  23.0  28.0  39.0
# Moving violation     11876.0  36.736443  13.258350  15.0  25.0  35.0  47.0
# Other                 3477.0  40.362381  12.754423  16.0  30.0  41.0  50.0
# Registration/plates   2240.0  32.656696  11.150780  16.0  24.0  30.0  40.0
# Seat belt                3.0  30.333333  10.214369  23.0  24.5  26.0  34.0
# Speeding             37120.0  33.262581  12.615781  15.0  23.0  30.0  42.0
#
#                       max
# violation
# Equipment            81.0
# Moving violation     86.0
# Other                86.0
# Registration/plates  74.0
# Seat belt            42.0
# Speeding             88.0
